# %% [markdown]
# <a href="https://colab.research.google.com/github/yashikasaraff7-hub/Personal-Grade-Calculator-/blob/main/Personal_Grade_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
test_scores = np.array([5,7,8,2,1])
print(test_scores)
# Out:
# [5 7 8 2 1]

# %%
mean = 0
for x in test_scores:
  #print(x)
 mean = mean + x
print(mean/len(test_scores)); print(test_scores.mean())
# Out:
# 4.6
# 4.6

# %%
median = len(test_scores)/2
print(int(median))
print(test_scores[int(median)])
# Out:
# 2
# 8

# %%
test_scores = np.array([5,7,8,2,1])
print(np.std(test_scores))
# Out:
# 2.727636339397171

# %%
my_mean = test_scores.mean()
for x in test_scores:
 differ = np.sum((x - my_mean) **2)
squared_value = differ.mean()
actual_value = np.sqrt(squared_value)

print(np.std(test_scores))
# Out:
# 2.727636339397171

# %%
my_mean = test_scores.mean()
total = 0
differ = (test_scores - my_mean) ** 2
prit()
